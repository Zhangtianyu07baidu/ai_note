# %%
from ai_note.note import AINote
note = AINote(True)
# Out:
# Index ai_note deleted: {'acknowledged': True}

# %%
note.save_work_record("2024-5-18", "我拜访了客户王刚，他是自来水的主任，他的联系方式是13823454563")
# Out:
# Document added: {'_index': 'ai_note', '_id': 'JXeHUpAB3zUZNq12Pkhg', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}

# %%
note.save_work_record("2024-5-19", "我拜访了客户李勇，他是电力公司的主任，他的联系方式是13823454564")
# Out:
# Document added: {'_index': 'ai_note', '_id': '32qHUpAB5B5HLhKmRQj7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 1, '_primary_term': 1}

# %%
note.save_work_record("2024-5-18", "我拜访了客户赵六，他是煤矿公司的主任，他的联系方式是13823454568")
# Out:
# Document added: {'_index': 'ai_note', '_id': '4GqHUpAB5B5HLhKmTQi6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 2, '_primary_term': 1}

# %%
note.save_work_record("2024-5-20", "我拜访了客户王刚，他是自来水的主任，他的联系方式是13823454563")
# Out:
# Document added: {'_index': 'ai_note', '_id': '4WqHUpAB5B5HLhKmVAhl', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 3, '_primary_term': 1}

# %%
print(note.query_work_record_within_time("客户王刚的信息", "2024-5-18", "2024-5-20", 2))
# Out:
# {'took': 37, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 4, 'relation': 'eq'}, 'max_score': 2.86617, 'hits': [{'_index': 'ai_note', '_id': 'JXeHUpAB3zUZNq12Pkhg', '_score': 2.86617, '_source': {'timestamp': 1715961600, 'content': '2024-5-18：我拜访了客户王刚，他是自来水的主任，他的联系方式是13823454563', 'vector': [0.0030848244205117226, -0.008132108487188816, 0.0008762178476899862, -0.022877434268593788, -0.008972201496362686, 0.026089953258633614, -0.007056788075715303, -0.0007313016685657203, -0.032501548528671265, 0.0014936868101358414, -0.002905044471845031, 0.022756461054086685, -0.011290861293673515, -0.019369203597307205, -0.007036625873297453, 0.01665402017533779, 0.017635248601436615, -0.032501548528671265, 0.023925872519612312, 0.0052892304956912994, -0.004492821637541056, 0.02086121030151844, 0.0033284516539424658, 0.008595840074121952, -0.014973832294344902, -0.0005153975798748434, 0.004909508395940065, -0.007406266871839762
# ...
